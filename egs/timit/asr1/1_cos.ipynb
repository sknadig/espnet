# %%
import torch
from torch.autograd import Variable
from torch.nn.modules.distance import CosineSimilarity
import matplotlib.pyplot as plt

# %%
a = Variable(torch.zeros(2,20), requires_grad = True)
b = torch.zeros(a.size())
a.data[0][3:7] = 1
b.data[0][3:5] = 1
a.data[1][1:3] = 1
b.data[1][8:10] = 1

# %%
for i in range(len(a)):
    plt.figure()
    fig, ax = plt.subplots(2,1)
    ax[0].plot(a[i].detach().numpy())
    ax[1].plot(b[i].detach().numpy())

# %%
cosine_distance = CosineSimilarity(dim=1)
cosine_loss = cosine_distance(a,b)

# %%
cosine_loss[1].backward()

# %%
for i in range(len(a)):
    plt.figure()
    fig, ax = plt.subplots(3,1)
    ax[0].plot(a[i].detach().numpy())
    ax[1].plot(b[i].detach().numpy())
    ax[2].plot(a.grad[i].numpy())
